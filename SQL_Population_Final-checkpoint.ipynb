# %%
import pandas as pd

# %%
df_projects = pd.read_csv('./Resources/Population_Gender.csv')

# %%
f = open('./Resources/Population_Gender.csv')
for i in range(10):
    line = f.readline()
    print('line: ', i,  line)
f.close()
# Out:
# line:  0 ï»¿Country Name,Country Code,Series Name,Series Code,2016 [YR2016],2017 [YR2017],2018 [YR2018],2019 [YR2019],2020 [YR2020],2021 [YR2021],2022 [YR2022],2023 [YR2023],2024 [YR2024],2025 [YR2025]
#
# line:  1 Afghanistan,AFG,"Population, female",SP.POP.TOTL.FE.IN,17196083,17644266,18079105,18512029,18952000,19400000,19854000,20311000,20768000,21223000
#
# line:  2 Afghanistan,AFG,"Population, female (% of total population)",SP.POP.TOTL.FE.ZS,48.5996676146541,48.611615718279,48.6358467017121,48.6623948520569,48.6845201032328,48.7014900404735,48.7158449330054,48.7284133060174,48.7406801341153,48.7536170053136
#
# line:  3 Afghanistan,AFG,"Population, male",SP.POP.TOTL.MA.IN,18187045,18652134,19093281,19529725,19976000,20435000,20901000,21371000,21841000,22308000
#
# ...

# %%
df_population_gender = pd.read_csv('./Resources/Population_Gender.csv',skiprows=0)
df_population_gender.head()
# Out:
#   Country Name Country Code                                 Series Name  \
# 0  Afghanistan          AFG                          Population, female
# 1  Afghanistan          AFG  Population, female (% of total population)
# 2  Afghanistan          AFG                            Population, male
# 3  Afghanistan          AFG    Population, male (% of total population)
# 4  Afghanistan          AFG                           Population, total
#
#          Series Code     2016 [YR2016]    2017 [YR2017]     2018 [YR2018]  \
# 0  SP.POP.TOTL.FE.IN          17196083         17644266          18079105
# 1  SP.POP.TOTL.FE.ZS  48.5996676146541  48.611615718279  48.6358467017121
# 2  SP.POP.TOTL.MA.IN          18187045         18652134          19093281
# 3  SP.POP.TOTL.MA.ZS  51.4003323853459  51.388384281721  51.3641532982879
# 4        SP.POP.TOTL          35383128         36296400          37172386
#
#       2019 [YR2019]     2020 [YR2020]     2021 [YR2021]     2022 [YR2022]  \
# ...

# %%
#Rename the column Series Name to Description
df_population_gender.rename(columns = {'Series Name':'Description'}, inplace = True) 
print("\nAfter modifying first column:\n", df_population_gender.columns)
# Out:
# After modifying first column:
#  Index(['Country Name', 'Country Code', 'Description', 'Series Code',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]',
#        '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]',
#        '2024 [YR2024]', '2025 [YR2025]'],
#       dtype='object')

# %%
# How many rows and columns? 
df_population_gender.shape
# Out:
# (1300, 14)

# %%
# Count the number of empty values in each column
df_population_gender.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Description      5
# Series Code      5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# 2018 [YR2018]    5
# 2019 [YR2019]    5
# 2020 [YR2020]    5
# 2021 [YR2021]    5
# 2022 [YR2022]    5
# 2023 [YR2023]    5
# 2024 [YR2024]    5
# 2025 [YR2025]    5
# dtype: int64

# %%
#Count the number of empty values in each row
df_population_gender.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1295    14
# 1296    14
# 1297    14
# 1298    13
# 1299    13
# Length: 1300, dtype: int64

# %%
# Identify rows that contains an empty value. Does it make sense? 
df_population_gender[df_population_gender.isnull().any(axis=1)]
# Out:
#                                            Country Name Country Code  \
# 1295                                                NaN          NaN
# 1296                                                NaN          NaN
# 1297                                                NaN          NaN
# 1298  Data from database: Population estimates and p...          NaN
# 1299                           Last Updated: 12/18/2020          NaN
#
#      Description Series Code 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 1295         NaN         NaN           NaN           NaN           NaN
# 1296         NaN         NaN           NaN           NaN           NaN
# 1297         NaN         NaN           NaN           NaN           NaN
# 1298         NaN         NaN           NaN           NaN           NaN
# 1299         NaN         NaN           NaN           NaN           NaN
#
#      2019 [YR2019] 2020 [YR2020] 2021 [YR2021] 2022 [YR2022] 2023 [YR2023]  \
# ...

# %%
# Drop rows the above rows with empty values.
df_population_gender_new = df_population_gender.dropna(how='all')

# %%
#Validate that the rows dropped using description count. There were 1300 rows before the drop and now there is 1295. 
df_population_gender_new.describe()
# Out:
#        Country Name Country Code       Description        Series Code  \
# count          1297         1295              1295               1295
# unique          261          259                 5                  5
# top           Aruba          LSO  Population, male  SP.POP.TOTL.FE.ZS
# freq              5            5               259                259
#
#        2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# count           1295          1295          1295          1295          1295
# unique          1185          1186          1184          1184          1153
# top               ..            ..            ..            ..            ..
# freq             102           102           102           102           106
#
#        2021 [YR2021] 2022 [YR2022] 2023 [YR2023] 2024 [YR2024] 2025 [YR2025]
# count           1295          1295          1295          1295          1295
# ...
